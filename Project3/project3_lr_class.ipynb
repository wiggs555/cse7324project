# %%
# dependencies for lab 1
import pandas as pd
import numpy as np
import missingno as msno
# use plotly in offline mode to not have active connection to plotly servers
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import warnings
#warnings.simplefilter('ignore', category=DeprecationWarning)
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
dc = pd.read_csv("C:/Users/sulem/OneDrive/Desktop/machin learnign/Project3/aac_shelter_cat_outcome_eng.csv")
dc.dropna
dc.drop(['breed2'], axis=1, inplace = True)
dc.drop(['outcome_weekday'], axis=1, inplace = True)
#dc.drop(['age_upon_outcome'], axis=1, inplace = True)
dc.drop(['sex_age_outcome'], axis=1, inplace = True)
dc.drop(['animal_type'], axis=1, inplace = True)
dc.drop(['color2'], axis=1, inplace = True)
dc.drop(['animal_id'], axis=1, inplace = True)
dc.drop(['date_of_birth'], axis=1, inplace = True)
dc.drop(['datetime'], axis=1, inplace = True)
dc.drop(['monthyear'], axis=1, inplace = True)
dc.drop(['name'], axis=1, inplace = True)
dc.drop(['count'], axis=1, inplace = True)
dc.drop(['outcome_subtype'], axis=1, inplace = True)
dc.drop(dc[(pd.isna(dc['coat_pattern']))].index, inplace=True)
dc.drop(dc[(pd.isna(dc['color']))].index, inplace=True)
dc.drop(dc[(pd.isna(dc['outcome_type']))].index, inplace=True)

msno.matrix(dc)

# %%
from sklearn.model_selection import train_test_split
x_test ,x_train = train_test_split(dc,test_size=0.8) 

x_train.shape

gender = {'Male': 1,'Female': 2} 
sp_ne={'No' : 1, 'Yes': 2}
ct_ki={'Kitten' :1, 'Cat':1}
t_f={'FALSE' : 1, False : 1, 'TRUE': 2 , True: 2}
dob={'2014-07' : 1,'2014-08' : 2,'2014-06' : 3,'2014-03' : 4,'2014-01' : 5,'2014-10' : 6,'2013-12' : 7,'2014-09' : 8,'2014-12' : 9,'2013-10' : 10,'2014-04' : 11,'2014-11' : 12,'2013-11' : 13,'2014-05' : 14,'2014-02' : 15,'2015-01' : 16,'2015-03' : 17,'2015-02' : 18,'2015-04' : 19,'2017-01' : 20,'2017-09' : 21,'2015-07' : 22,'2016-05' : 23,'2017-04' : 24,'2016-09' : 25,'2017-10' : 26,'2017-07' : 27,'2015-11' : 28,'2017-06' : 29,'2017-05' : 30,'2015-06' : 31,'2015-05' : 32,'2016-07' : 33,'2015-10' : 34,'2016-12' : 35,'2017-08' : 36,'2016-02' : 37,'2015-09' : 38,'2016-08' : 39,'2017-02' : 40,'2015-12' : 41,'2015-08' : 42,'2016-03' : 43,'2016-06' : 44,'2016-01' : 45,'2016-04' : 46,'2017-11' : 47,'2017-03' : 48,'2016-10' : 49,'2016-11' : 50,'2017-12' : 51,'2018-01' : 52,'2018-02' : 53}
age={'(-0.022, 2.2]' : 1,'(2.2, 4.4]' : 2,'(6.6, 8.8]' : 3,'(4.4, 6.6]' : 4,'(8.8, 11.0]' : 5,'(13.2, 15.4]' : 6,'(15.4, 17.6]' : 7,'(11.0, 13.2]' : 8,'(19.8, 22.0]' : 9,'(17.6, 19.8]' : 10}
gender_upon_outcome = {'Intact Male': 1,'Intact Female': 0 ,'Spayed Male': 1.1,'Spayed Female': 0.1, 'Neutered Male': 1.2,'Neutered Female': 0.2}
col2={'' : 1,'white' : 2,'black' : 3,'orange' : 4,'blue' : 5,'seal' : 6,'brown' : 7,'blue cream' : 8,'lynx' : 9,'red' : 10,'cream' : 11,'gray' : 12,'buff' : 13,'chocolate' : 14,'silver' : 15,'flame' : 16,'tan' : 17,'apricot' : 18,'yellow' : 19,'lilac' : 20}
cot={'orange' : 1,'blue ' : 2,'white' : 3,'black' : 4,'brown' : 5,'brown ' : 6,'seal' : 7,'torbie' : 8,'blue' : 9,'cream ' : 10,'calico' : 11,'chocolate' : 12,'orange ' : 13,'silver' : 14,'flame' : 15,'tortie' : 16,'cream' : 17,'lynx' : 18,'seal ' : 19,'lilac' : 20,'buff' : 21,'blue cream' : 22,'black ' : 23,'silver lynx' : 24,'gray' : 25,'gray ' : 26,'yellow' : 27,'apricot' : 28,'lynx ' : 29,'chocolate ' : 30,'silver ' : 31,'lilac ' : 32,'brown tiger' : 33,'black tiger' : 34,'tan' : 35,'orange tiger' : 36,'agouti' : 37,'flame ' : 38,'silver lynx ' : 39,'tricolor' : 40,'sable' : 41,'pink' : 42,'brown merle' : 43,'fawn' : 44}
# traversing through dataframe 
# Gender column and writing 
# values where key matches 
x_train.sex = [gender[item] for item in x_train.sex] 
x_train.breed = [brd[item] for item in x_train.breed] 
x_train.color = [clr[item] for item in x_train.color]
x_train.outcome_type = [out_t[item] for item in x_train.outcome_type]
x_train.sex_upon_outcome = [sex_u_o[item] for item in x_train.sex_upon_outcome]
x_train['Spay/Neuter']= [sp_ne[item] for item in x_train['Spay/Neuter']]
x_train['Cat/Kitten (outcome)']= [ct_ki[item] for item in x_train['Cat/Kitten (outcome)']]
x_train.breed1 = [br1[item] for item in x_train.breed1]
#x_train.breed2 = [br2[item] for item in x_train.breed2]
x_train.cfa_breed = [t_f[item] for item in x_train.cfa_breed]
x_train.domestic_breed = [t_f[item] for item in x_train.domestic_breed]
x_train.coat_pattern = [co_p[item] for item in x_train.coat_pattern]
x_train.color1 = [co1[item] for item in x_train.color1]
#x_train.color2 = [col2[item] for item in x_train.color2]
x_train.coat = [cot[item] for item in x_train.coat]
x_train.age_group = [age[item] for item in x_train.age_group]    
x_train.dob_monthyear = [dob[item] for item in x_train.dob_monthyear]

y_target= x_train.outcome_type
x_train.drop(['outcome_type'], axis=1, inplace = True)

# %%
from scipy.special import expit
class LogisticRegression:  
                           
    def __init__(self, eta, iterations=20,C=.00001):
        self.eta = eta
        self.iters = iterations
        self.C = C
        
        # internally we will store the weights as self.w_ to keep with sklearn conventions
    
    def __str__(self):
        if(hasattr(self,'w_')):
            return 'MultiClass Logistic Regression Object with coefficients:\n'+ str(self.w_) # is we have trained the object
        else:
            return 'Untrained MultiClass Logistic Regression Object'
        
    def fitm(self,X,y):
        num_samples, num_features = X.shape
        self.unique_ = np.unique(y) # get each unique class value
        num_unique_classes = len(self.unique_)
        self.classifiers_ = [] # will fill this array with binary classifiers
        
        for i,yval in enumerate(self.unique_): # for each unique value
            y_binary = (y==yval) # create a binary problem
            # train the binary classifier for this class
            #blr = VectorBinaryLogisticRegression(self.eta,self.iters)
            self.fit(X,y_binary)
            # add the trained classifier to the list
            self.classifiers_.append(self)
            
        # save all the weights into one matrix, separate column for each class
        self.w_ = np.hstack([x.w_ for x in self.classifiers_])
        
    def predict_proba(self,X,add_bias=True):
        # add bias term if requested
        Xb = self._add_bias(X) if add_bias else X
        return self._sigmoid(Xb @ self.w_).T # return the probability y=1
    
    def predict(self,X):
        return (self.predict_proba(X)>0.5) #return the actual prediction
    
    def predict_probam(self,X):
        probs = []
        for blr in self.classifiers_:
            probs.append(blr.predict_proba(X)) # get probability for each classifier
        
        return np.hstack(probs) # make into single matrix
    def _add_bias(self,X):
        return np.hstack((np.ones((X.shape[0],1)),X)) # add bias term
    def predictm(self,X):
        return np.argmax(self.predict_probam(X),axis=1) # take argmax along row
    
    def _sigmoid(self,theta):
        # increase stability, redefine sigmoid operation
        return expit(theta) #1/(1+np.exp(-theta))
    
    # but overwrite the gradient calculation
    def _get_gradient(self,X,y):
        ydiff = y-self.predict_proba(X,add_bias=False).ravel() # get y difference
        gradient = np.mean(X * ydiff[:,np.newaxis], axis=0) # make ydiff a column vector and multiply through
        
        gradient = gradient.reshape(self.w_.shape)
        gradient[1:] += -2 * self.w_[1:] * self.C 
        
        return gradient/float(len(y))
    def fit(self, X, y):
        Xb = np.hstack((np.ones((X.shape[0],1)),X))# add bias term
        num_samples, num_features = Xb.shape
        
        self.w_ = np.zeros((num_features,1)) # init weight vector to zeros
        
        # for as many as the max iterations
        for _ in range(self.iters):
            gradient = self._get_gradient(Xb,y)
            self.w_ += gradient*self.eta # multiply by learning rate     
lr = LogisticRegression(0.1,500)
print(lr)
# Out:
# Untrained MultiClass Logistic Regression Object

# %%
from sklearn.metrics import accuracy_score
x_train_ar=x_train.values
y_target_ar=y_target.values
lr = LogisticRegression(.2,100)
lr.fitm(x_train_ar,y_target_ar)
print(lr)

yhat = lr.predictm(x_train_ar)
print('Accuracy of: ',accuracy_score(y_target_ar,yhat))
# Out:
# MultiClass Logistic Regression Object with coefficients:
# [[-5.97611902e-06 -5.97611902e-06 -5.97611902e-06 -5.97611902e-06
#   -5.97611902e-06 -5.97611902e-06 -5.97611902e-06 -5.97611902e-06]
#  [-2.31743039e-03 -2.31743039e-03 -2.31743039e-03 -2.31743039e-03
#   -2.31743039e-03 -2.31743039e-03 -2.31743039e-03 -2.31743039e-03]
#  [-1.29669402e-05 -1.29669402e-05 -1.29669402e-05 -1.29669402e-05
#   -1.29669402e-05 -1.29669402e-05 -1.29669402e-05 -1.29669402e-05]
#  [-5.39496504e-05 -5.39496504e-05 -5.39496504e-05 -5.39496504e-05
#   -5.39496504e-05 -5.39496504e-05 -5.39496504e-05 -5.39496504e-05]
#  [-1.81519019e-05 -1.81519019e-05 -1.81519019e-05 -1.81519019e-05
#   -1.81519019e-05 -1.81519019e-05 -1.81519019e-05 -1.81519019e-05]
#  [-9.05586429e-06 -9.05586429e-06 -9.05586429e-06 -9.05586429e-06
#   -9.05586429e-06 -9.05586429e-06 -9.05586429e-06 -9.05586429e-06]
#  [-9.52239420e-06 -9.52239420e-06 -9.52239420e-06 -9.52239420e-06
# ...

# %%
y_target_ar
# Out:
# array([2, 2, 1, ..., 2, 1, 2], dtype=int64)

# %%
yhat
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
